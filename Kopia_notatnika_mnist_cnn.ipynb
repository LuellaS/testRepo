# %% [markdown]
# <a href="https://colab.research.google.com/github/LuellaS/testRepo/blob/main/Kopia_notatnika_mnist_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Trains a simple deep NN on the MNIST dataset.

Gets to 99.6% test accuracy after 40 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.optimizers import RMSprop, Adam, Adadelta

from keras.utils.vis_utils import plot_model
from IPython.display import Image 
from keras.preprocessing.image import ImageDataGenerator
batch_size = 128
num_classes = 10
epochs = 50

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train0), (x_test, y_test0) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)



x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train0, num_classes)
y_test = keras.utils.to_categorical(y_test0, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %%
N_TRAIN_EXAMPLES = 1000 #3000
N_TEST_EXAMPLES = 10000
x_train = x_train[:N_TRAIN_EXAMPLES]
x_test = x_test[:N_TEST_EXAMPLES]
y_train = y_train[:N_TRAIN_EXAMPLES]
y_test = y_test[:N_TEST_EXAMPLES]

# %%
# set up image augmentation
datagen = ImageDataGenerator( 
    rotation_range=30,
    horizontal_flip=False,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.70,1.1]
    )
datagen.fit(x_train)

# %%
print(x_train.reshape((len(x_train),img_rows, img_cols)).shape)
# see example augmentation images
fig = plt.figure(figsize=(12, 12))
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
         plt.subplot(330 + 1 + i)
         plt.imshow(X_batch[i].reshape((img_rows, img_cols)))
         plt.axis('off')
    plt.show()
    break
# Out:
# (1000, 28, 28)

# %%
# see example augmentation images
fig = plt.figure(figsize=(12, 12))

for i in range(0, 25):
    for X_batch, y_batch in datagen.flow(x_train[4:6], y_train[4:6], batch_size=1, shuffle=False):
         plt.subplot(5,5,i+1)
         plt.imshow(X_batch[0].reshape((img_rows, img_cols)), cmap=plt.cm.binary, interpolation='nearest')
         plt.axis('off')
         break

plt.show()

# %%
#visualize the digits
fig = plt.figure(figsize=(10, 10)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
# generate augmented plot
X_train, Y_train = datagen.flow(x_train,y_train, batch_size=100).next()
for i in range(100):
  ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
  ax.imshow(X_train[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')
  # label the image with the target value
  ax.text(0, 7, str(np.argmax(Y_train[i])))

# %%
# Our old fully connected (dense) network
#model = Sequential()
#model.add(Dense(512, activation='relu', input_shape=(784,)))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(num_classes, activation='softmax'))

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))



model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               131200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 225,162
# Trainable params: 225,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
Image('model_plot.png')

# %%
from keras.callbacks import EarlyStopping
model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])
early_stoping=EarlyStopping(patience=12,verbose=1)

history = model.fit(datagen.flow(x_train, y_train,
                    batch_size=batch_size),
                    epochs=epochs,
                    batch_size=batch_size,
                    verbose=1,
                    validation_data=(x_test, y_test), callbacks=[early_stoping])
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 80ms/step - loss: 0.3667 - accuracy: 0.8900 - val_loss: 0.1077 - val_accuracy: 0.9636
# Epoch 2/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3782 - accuracy: 0.8870 - val_loss: 0.0877 - val_accuracy: 0.9717
# Epoch 3/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3613 - accuracy: 0.8820 - val_loss: 0.0848 - val_accuracy: 0.9740
# Epoch 4/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.3336 - accuracy: 0.9040 - val_loss: 0.0776 - val_accuracy: 0.9756
# Epoch 5/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.3532 - accuracy: 0.9070 - val_loss: 0.1036 - val_accuracy: 0.9675
# Epoch 6/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.3100 - accuracy: 0.9000 - val_loss: 0.0753 - val_accuracy: 0.9756
# Epoch 7/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.3338 - accuracy: 0.8960 - val_loss: 0.0749 - val_accuracy: 0.9757
# Epoch 8/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.3080 - accuracy: 0.9070 - val_loss: 0.0823 - val_accuracy: 0.9747
# Epoch 9/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.2777 - accuracy: 0.9130 - val_loss: 0.0947 - val_accuracy: 0.9698
# Epoch 10/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.3242 - accuracy: 0.8890 - val_loss: 0.0740 - val_accuracy: 0.9767
# Epoch 11/50
# 8/8 [==============================] - 0s 59ms/step - loss: 0.3228 - accuracy: 0.9090 - val_loss: 0.0756 - val_accuracy: 0.9764
# Epoch 12/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3017 - accuracy: 0.9140 - val_loss: 0.0675 - val_accuracy: 0.9778
# Epoch 13/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2270 - accuracy: 0.9240 - val_loss: 0.0720 - val_accuracy: 0.9754
# Epoch 14/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2567 - accuracy: 0.9240 - val_loss: 0.0819 - val_accuracy: 0.9734
# Epoch 15/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.3198 - accuracy: 0.9060 - val_loss: 0.0753 - val_accuracy: 0.9773
# Epoch 16/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2933 - accuracy: 0.9080 - val_loss: 0.0780 - val_accuracy: 0.9751
# Epoch 17/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2843 - accuracy: 0.9290 - val_loss: 0.0728 - val_accuracy: 0.9771
# Epoch 18/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2372 - accuracy: 0.9290 - val_loss: 0.0687 - val_accuracy: 0.9781
# Epoch 19/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2425 - accuracy: 0.9240 - val_loss: 0.0724 - val_accuracy: 0.9771
# Epoch 20/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2636 - accuracy: 0.9110 - val_loss: 0.0676 - val_accuracy: 0.9784
# Epoch 21/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2887 - accuracy: 0.9150 - val_loss: 0.0786 - val_accuracy: 0.9749
# Epoch 22/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2507 - accuracy: 0.9350 - val_loss: 0.0722 - val_accuracy: 0.9772
# Epoch 23/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2463 - accuracy: 0.9280 - val_loss: 0.0671 - val_accuracy: 0.9795
# Epoch 24/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2521 - accuracy: 0.9310 - val_loss: 0.0645 - val_accuracy: 0.9781
# Epoch 25/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2362 - accuracy: 0.9360 - val_loss: 0.0685 - val_accuracy: 0.9777
# Epoch 26/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2286 - accuracy: 0.9330 - val_loss: 0.0613 - val_accuracy: 0.9796
# Epoch 27/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2397 - accuracy: 0.9290 - val_loss: 0.0635 - val_accuracy: 0.9805
# Epoch 28/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2299 - accuracy: 0.9350 - val_loss: 0.0652 - val_accuracy: 0.9788
# Epoch 29/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2321 - accuracy: 0.9220 - val_loss: 0.0885 - val_accuracy: 0.9726
# Epoch 30/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2397 - accuracy: 0.9290 - val_loss: 0.0740 - val_accuracy: 0.9767
# Epoch 31/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2516 - accuracy: 0.9260 - val_loss: 0.0729 - val_accuracy: 0.9765
# Epoch 32/50
# 8/8 [==============================] - 0s 59ms/step - loss: 0.2494 - accuracy: 0.9250 - val_loss: 0.0645 - val_accuracy: 0.9790
# Epoch 33/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2745 - accuracy: 0.9140 - val_loss: 0.0672 - val_accuracy: 0.9777
# Epoch 34/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2280 - accuracy: 0.9280 - val_loss: 0.0640 - val_accuracy: 0.9791
# Epoch 35/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1988 - accuracy: 0.9390 - val_loss: 0.0604 - val_accuracy: 0.9809
# Epoch 36/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2082 - accuracy: 0.9440 - val_loss: 0.0592 - val_accuracy: 0.9806
# Epoch 37/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.2161 - accuracy: 0.9290 - val_loss: 0.0595 - val_accuracy: 0.9807
# Epoch 38/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1751 - accuracy: 0.9490 - val_loss: 0.0665 - val_accuracy: 0.9787
# Epoch 39/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1740 - accuracy: 0.9460 - val_loss: 0.0712 - val_accuracy: 0.9776
# Epoch 40/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2144 - accuracy: 0.9310 - val_loss: 0.0592 - val_accuracy: 0.9816
# Epoch 41/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1783 - accuracy: 0.9430 - val_loss: 0.0607 - val_accuracy: 0.9809
# Epoch 42/50
# 8/8 [==============================] - 1s 64ms/step - loss: 0.2292 - accuracy: 0.9400 - val_loss: 0.0649 - val_accuracy: 0.9795
# Epoch 43/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2077 - accuracy: 0.9460 - val_loss: 0.0617 - val_accuracy: 0.9796
# Epoch 44/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2007 - accuracy: 0.9370 - val_loss: 0.0647 - val_accuracy: 0.9788
# Epoch 45/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1834 - accuracy: 0.9440 - val_loss: 0.0557 - val_accuracy: 0.9817
# Epoch 46/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1522 - accuracy: 0.9510 - val_loss: 0.0539 - val_accuracy: 0.9830
# Epoch 47/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1762 - accuracy: 0.9590 - val_loss: 0.0647 - val_accuracy: 0.9779
# Epoch 48/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1888 - accuracy: 0.9350 - val_loss: 0.0594 - val_accuracy: 0.9798
# Epoch 49/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1778 - accuracy: 0.9380 - val_loss: 0.0597 - val_accuracy: 0.9794
# Epoch 50/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2101 - accuracy: 0.9320 - val_loss: 0.0541 - val_accuracy: 0.9820

# %%
# Plots for training and testing process: loss and accuracy

n_epochs = len(history.history['loss'])

plt.figure(0)
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Cat_Accuracy vs Validation Cat_Accuracy")
plt.legend(['train','validation'])

# %%
plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.08156152069568634
# Test accuracy: 0.9742000102996826

# %%
# evaluate loaded model
scores_train = model.evaluate(x_train, y_train, verbose=0)
scores_test  = model.evaluate(x_test,  y_test,  verbose=0)

print("Accuracy Train: %.2f%% , Test: %.2f%% " % (scores_train[1]*100, scores_test[1]*100 ))
# Out:
# Accuracy Train: 98.30% , Test: 97.42%

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model.predict(x_test, verbose=2)

y_pred = np.argmax(Y_pred, axis=1)

y_test2 = np.argmax(y_test, axis=1)



#confusion matrix
cm = confusion_matrix(np.argmax(y_test,axis=1),y_pred)
print(cm)
# Out:
# 313/313 - 0s
# [[ 952    0    3    1    4    0    5    2    0   13]
#  [   0 1118    2    5    1    1    4    4    0    0]
#  [   1    0 1014    3    0    0    1   12    1    0]
#  [   0    0    2  995    0    6    0    3    2    2]
#  [   1    0    1    0  940    0    3    0    0   37]
#  [   0    1    0    6    0  882    2    0    0    1]
#  [   4    3    0    0    2    5  944    0    0    0]
#  [   1    1   13    8    2    1    0  984    1   17]
#  [   4    0    8    1    8    3    1    1  926   22]
#  [   1    0    0    3    5    9    0    3    1  987]]

# %%
# Visualizing of confusion matrix
import seaborn as sn
import pandas  as pd


df_cm = pd.DataFrame(cm, range(10),range(10))
#                     range(num_classes),
#                  range(num_classes))
#plt.figure(figsize = (10,7))
plt.figure(2,figsize = (15,15) )
sn.set(font_scale=1.4) #for label size
sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
plt.show()

# %%
# use the model to predict the labels of the test data
predicted = model.predict(x_test)
expected = y_test0



# Plot the prediction
fig = plt.figure(figsize=(20, 20))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)


# plot the digits: each image is 28x28 pixels
for i in range(400):
    ax = fig.add_subplot(20, 20, i + 1, xticks=[], yticks=[])
    ax.imshow(x_test[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')

    # label the image with the target value
    if np.argmax(predicted[i]) == expected[i]:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='green')
    else:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='red')

# %%
# Creates the graph.png file

! pip3 install keras-visualizer
from keras_visualizer import visualizer  

#create the graph.png image
visualizer(model=model, view=True, format='png', filename='graph')

#show the graph
import matplotlib.image as mpimg
img = mpimg.imread('graph.png')
imgplot = plt.imshow(img,)
plt.show()
# Out:
# Requirement already satisfied: keras-visualizer in /usr/local/lib/python3.6/dist-packages (2.4)
